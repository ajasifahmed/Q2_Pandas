# %%
import numpy as np
import pandas as pd
import csv

# %%
with open('mydata.txt', 'w') as f:
    writer = csv.writer(f,delimiter='|')
    writer.writerow(('one', 'two', 'three'))
    writer.writerow(('1', '2', '3'))
    writer.writerow(('4', '5', '6'))
    writer.writerow(('7', '8', '9'))

# %%
with open("mydata.txt","r") as r:
    text=r.read()
    print(text)
# Out:
# one|two|three
#
# 1|2|3
#
# 4|5|6
#
# 7|8|9

# %%
x=np.array([1,4,5,3])
y=np.array([2,3,2,42])

# %%
np.save('arrayx.npy',x)

# %%
load=np.load('arrayx.npy')
load
# Out:
# array([1, 4, 5, 3])

# %%
np.savez('arxy.npz',x=x,y=y)

# %%
lod=np.load('arxy.npz')

# %%
lod

# %%
lod['y']
# Out:
# array([ 2,  3,  2, 42])

# %%
np.savez_compressed("arxy_compressed.npz",x=x,y=y)

# %%
lod=np.load('arxy_compressed.npz')

# %%
lod['x']
# Out:
# array([1, 4, 5, 3])

# %%
np.ones(3)
# Out:
# array([1., 1., 1.])

# %%
l=pd.read_csv('yob1880.txt',names=['Names','F','Sno'])
l.head()
# Out:
#        Names  F   Sno
# 0       Mary  F  7065
# 1       Anna  F  2604
# 2       Emma  F  2003
# 3  Elizabeth  F  1939
# 4     Minnie  F  1746

# %%
dic={'asif':['b17101021','21121997']}
u=pd.read_csv('untitled.txt',sep='\s+',na_values=dic)
u
# Out:
#      name  is  asif
# 0     dob  is   NaN
# 1  seatno  is   NaN

# %%
u=pd.read_csv('untitled.txt',index_col=['key1','key2'])
u.columns.name='CLOUMNS'
u
# Out:
# CLOUMNS    value1  value2
# key1 key2
# one  a          1       2
#      b          3       4
#      c          5       6
#      d          7       8
# two  a          9      10
#      b         11      12
#      c         13      14
#      d         15      16

# %%
r=pd.read_csv('train.csv',nrows=200)
r
#r.nsmallest(5, ['int_memory'])
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0              842     0          2.2         0   1       0           7
# 1             1021     1          0.5         1   0       1          53
# 2              563     1          0.5         1   2       1          41
# 3              615     1          2.5         0   0       0          10
# 4             1821     1          1.2         0  13       1          44
# 5             1859     0          0.5         1   3       0          22
# 6             1821     0          1.7         0   4       1          10
# 7             1954     0          0.5         1   0       0          24
# 8             1445     1          0.5         0   0       0          53
# 9              509     1          0.6         1   2       1           9
# 10             769     1          2.9         1   0       0           9
# 11            1520     1          2.2         0   5       1          33
# ...

# %%
c=pd.read_csv('train.csv',chunksize=200)
chunklist=[]

for chunk in c:
    chunklist.append(chunk)
chunklist[2]
# Out:
#      battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 400           1266     0          1.9         1   0       1           7
# 401           1042     0          2.7         1  16       1          50
# 402           1479     0          0.5         0   8       0          19
# 403           1476     1          1.2         1   0       1          55
# 404           1552     1          2.2         0   6       1          13
# 405           1454     1          0.5         1   1       0          34
# 406           1007     0          2.0         0   0       0          45
# 407            652     1          2.4         1   9       1          17
# 408           1504     0          1.5         0  12       1          34
# 409           1726     1          0.9         1   2       0          51
# 410           1029     1          1.9         1   5       1           5
# 411           1582     0          2.8         0   2       1          44
# ...
