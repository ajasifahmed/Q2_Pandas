# %%
import pandas as pd
import numpy as np
import csv

# %%
e=pd.read_csv('earthquakes.csv')
df=pd.DataFrame(e)
df.columns = [col.upper() for col in df.columns]

# uc=df.columns.str.upper()
# df=pd.DataFrame(e,columns=uc)
df.head()
# Out:
#                       TIME   LATITUDE  LONGITUDE  DEPTH   MAG MAGTYPE  NST  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       GAP     DMIN     RMS NET          ID                   UPDATED  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                PLACE        TYPE
# 0  26km S of Redoubt Volcano, Alaska  earthquake
# ...

# %%
df.describe()
# Out:
#             LATITUDE      LONGITUDE          DEPTH            MAG  \
# count  120108.000000  120108.000000  120107.000000  120065.000000
# mean       38.399579     -99.961402      28.375029       1.793958
# std        21.938258      82.996858      62.215416       1.343466
# min       -73.462000    -179.998900      -9.900000      -0.970000
# 25%        34.228917    -147.742025       4.100000       0.820000
# 50%        38.805300    -120.832000       9.200000       1.400000
# 75%        53.889500    -116.068100      22.880000       2.400000
# max        86.651400     179.998000     697.360000       8.200000
#
#                 NST           GAP          DMIN            RMS
# count  59688.000000  94935.000000  85682.000000  119716.000000
# mean      17.878284    124.048978      0.893198       0.358174
# std       14.911369     68.518595      2.903966       0.364046
# min        0.000000      9.000000      0.000000       0.000000
# ...

# %%
sort=df.sort_values(by='MAG',ascending=False)
twenty=sort.iloc[:20]
twenty
# Out:
#                            TIME  LATITUDE  LONGITUDE   DEPTH  MAG MAGTYPE  \
# 37371   2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww
# 50562   2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww
# 36918   2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww
# 33808   2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww
# 31496   2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww
# 33537   2014-04-13 12:36:19.230  -11.4633   162.0511   39.00  7.4     mww
# 95913   2014-10-14 03:51:34.460   12.5262   -88.1225   40.00  7.3     mww
# 31850   2014-04-18 14:27:24.920   17.3970  -100.9723   24.00  7.2     mww
# 34318   2014-04-11 07:07:23.130   -6.5858   155.0485   60.53  7.1     mww
# 106285  2014-11-15 02:31:41.720    1.8929   126.5217   45.00  7.1     mww
# 111052  2014-11-01 18:57:22.380  -19.6903  -177.7587  434.00  7.1     mww
# 97602   2014-10-09 02:14:31.440  -32.1082  -110.8112   16.54  7.0     mww
# ...

# %%
# # importing pandas module 
# import pandas as pd 

# # reading csv file from url 
# data = pd.read_csv("https://media.geeksforgeeks.org/wp-content/uploads/nba.csv") 

# dropping null value columns to avoid errors 
#df.dropna(inplace = True)
df.dropna()

# new data frame with split value columns 
new = df["PLACE"].str.split(",", n = 1, expand = True) 

# making separate first name column from new data frame 
df["LOCATION"]= new[0] 

# making separate last name column from new data frame 
df["Country"]= new[1] 

# Dropping old Name columns 
#df.drop(columns =["PLACE"], inplace = True) i deleted it on second run
df.drop(columns =["PLACE"])
# df display 
df
# Out:
#                            TIME   LATITUDE   LONGITUDE    DEPTH   MAG MAGTYPE  \
# 0       2014-01-31 23:53:37.000  60.252000 -152.708100   90.200  1.10      ml
# 1       2014-01-31 23:48:35.452  37.070300 -115.130900    0.000  1.33      ml
# 2       2014-01-31 23:47:24.000  64.671700 -149.252800    7.100  1.30      ml
# 3       2014-01-31 23:30:54.000  63.188700 -148.957500   96.500  0.80      ml
# 4       2014-01-31 23:30:52.210  32.616833 -115.692500   10.590  1.34      ml
# 5       2014-01-31 23:30:36.930  32.567667 -117.013500    0.010  1.51      ml
# 6       2014-01-31 23:28:04.020  33.359000 -116.360500   12.980  1.17      ml
# 7       2014-01-31 23:22:52.000  62.800200 -150.696500   86.400  1.50      ml
# 8       2014-01-31 23:20:42.000  58.169500 -151.992400   50.100  2.10      ml
# 9       2014-01-31 23:17:34.300  37.686000 -121.728700    4.200  1.60      Md
# 10      2014-01-31 23:08:03.660  -4.975800  153.946600  110.180  4.20      mb
# ...

# %%
df.head()
# Out:
#                       TIME   LATITUDE  LONGITUDE  DEPTH   MAG MAGTYPE  NST  \
# 0  2014-01-31 23:53:37.000  60.252000  -152.7081  90.20  1.10      ml  NaN
# 1  2014-01-31 23:48:35.452  37.070300  -115.1309   0.00  1.33      ml  4.0
# 2  2014-01-31 23:47:24.000  64.671700  -149.2528   7.10  1.30      ml  NaN
# 3  2014-01-31 23:30:54.000  63.188700  -148.9575  96.50  0.80      ml  NaN
# 4  2014-01-31 23:30:52.210  32.616833  -115.6925  10.59  1.34      ml  6.0
#
#       GAP     DMIN     RMS NET          ID                   UPDATED  \
# 0     NaN      NaN  0.2900  ak  ak11155107  2014-02-05T19:34:41.515Z
# 1  171.43  0.34200  0.0247  nn  nn00436847  2014-02-01T01:35:09.000Z
# 2     NaN      NaN  1.0000  ak  ak11151142  2014-02-01T00:03:53.010Z
# 3     NaN      NaN  1.0700  ak  ak11151135  2014-01-31T23:41:25.007Z
# 4  285.00  0.04321  0.2000  ci  ci37171541  2014-02-01T00:13:20.107Z
#
#                                PLACE        TYPE                   LOCATION  \
# ...

# %%
se=df[['Country','MAG']]
se=se.sort_values(by='MAG',ascending=False)
df1=se

display(se.head(20))
display(df.nsmallest(20, 'MAG'))

# se['MAG'].max()
# se['MAG'].min()
# strongest=se.iloc[[se['MAG'].max()]]
# #weakest=se.iloc[[]]
# se['MAG'].min()
# display(df.loc[df['MAG'].idxmax()])
# print()
# display(df.loc[df['MAG'].idxmin()])
# Out:
#                   Country  MAG
# 37371               Chile  8.2
# 50562              Alaska  7.9
# 36918               Chile  7.7
# 33808     Solomon Islands  7.6
# 31496    Papua New Guinea  7.5
# 33537     Solomon Islands  7.4
# 95913         El Salvador  7.3
# 31850              Mexico  7.2
# 34318    Papua New Guinea  7.1
# 106285          Indonesia  7.1
# 111052               Fiji  7.1
# 97602                None  7.0
# 47934                      6.9
# 78063                None  6.9
# 50609         New Zealand  6.9
# 14025               China  6.9
# 61294                Fiji  6.9
# 37367               Chile  6.9
# 39915              Greece  6.9
# 66278              Mexico  6.9
#                            TIME  LATITUDE   LONGITUDE  DEPTH   MAG MAGTYPE  \
# 116943  2014-12-11 17:13:30.400   43.7200 -121.315333   1.58 -0.97      md
# 57895   2014-07-31 07:53:05.200   46.1962 -122.171200   1.80 -0.90      Md
# ...

# %%
df.nlargest(5, 'MAG')
# Out:
#                           TIME  LATITUDE  LONGITUDE   DEPTH  MAG MAGTYPE  NST  \
# 37371  2014-04-01 23:46:47.260  -19.6097   -70.7691   25.00  8.2     mww  NaN
# 50562  2014-06-23 20:53:09.700   51.8486   178.7352  109.00  7.9     mww  NaN
# 36918  2014-04-03 02:43:13.110  -20.5709   -70.4931   22.40  7.7     mww  NaN
# 33808  2014-04-12 20:14:39.300  -11.2701   162.1481   22.56  7.6     mww  NaN
# 31496  2014-04-19 13:28:00.810   -6.7547   155.0241   43.37  7.5     mww  NaN
#
#         GAP   DMIN   RMS NET          ID                   UPDATED  \
# 37371  23.0  0.609  0.66  us  usc000nzvd  2015-07-30T16:24:51.223Z
# 50562  22.0  0.133  0.71  us  usc000rki5  2015-04-18T21:54:08.699Z
# 36918  44.0  1.029  0.82  us  usc000p27i  2015-06-06T07:31:05.755Z
# 33808  13.0  2.828  0.71  us  usc000phx5  2015-04-18T21:54:27.398Z
# 31496  16.0  3.820  1.25  us  usb000pr89  2015-04-18T21:54:18.633Z
#
#                                          PLACE        TYPE  \
# ...

# %%
df['Country'].value_counts().head(5)
# Out:
#  California    44451
#  Alaska        33589
#  Oregon         3195
#  Nevada         2858
#  Washington     2784
# Name: Country, dtype: int64

# %%
#pip install us

# %%
import us as u

# %%
# us_states=pd.DataFrame(u.states.STATES,columns=['US_States']).head(5)
# us_states
lst=list(u.states.STATES)
seri=pd.Series(lst)
# seri.reindex(range(120108), method='ffill')
df2=pd.DataFrame(seri,columns=['US'])

# %%
# seri.reindex=np.arange(120103)
# seri.index

# %%
# #drop=df.dropna()
# # drop['Country'].str.contains('Nevada')
# df1['D'] = np.where((df1['Country']==(seri['US'])), True, False)
# df1
#df1.Country.isin(df2['US'])

# %%
# df1['eastern'] = se.Country in seri.US

# %%
data = pd.DataFrame({'Qu1': [1, 3, 4, 3, 4],'Qu2': [2, 3, 1, 2, 3]})
data
# Out:
#    Qu1  Qu2
# 0    1    2
# 1    3    3
# 2    4    1
# 3    3    2
# 4    4    3
